# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install ultralytics --upgrade --quiet
from ultralytics import YOLO
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 15.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 72.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 62.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 43.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 10.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 81.5 MB/s eta 0:00:00
# Creating new Ultralytics Settings v0.0.6 file ✅
# ...

# %%
model = YOLO('yolov8n.pt')  # or 'yolov8s.pt', 'yolov8m.pt' based on GPU
import os

file_path = '/content/drive/MyDrive/FINAL_DATA-1/data.yaml'
if not os.path.exists(file_path):
    print(f"Error: The file '{file_path}' does not exist. Please check the file path.")
else:
    print(f"File '{file_path}' found. Proceeding with training.")
    model = YOLO('yolov8n.pt')  # or 'yolov8s.pt', 'yolov8m.pt' based on GPU
    model.train(data=file_path, epochs=50, imgsz=640)
# Out:
# ...
# 100%|██████████| 6.25M/6.25M [00:00<00:00, 74.3MB/s]
# File '/content/drive/MyDrive/FINAL_DATA-1/data.yaml' found. Proceeding with training.
# Ultralytics 8.3.158 🚀 Python-3.11.13 torch-2.6.0+cu124 CPU (Intel Xeon 2.20GHz)
# ...

# %%
model = YOLO('/content/runs/detect/train2/weights/best.pt')  # Load the best trained model

results = model.predict(
    source='/content/drive/MyDrive/Real_time_detection_using_yolov/valid/images',
    conf=0.25,
    save=True  # Saves annotated images to runs/detect/predict/
)
# Out:
# image 1/513 /content/drive/MyDrive/Real_time_detection_using_yolov/valid/images/0085364b2034b946_jpg.rf.70ae3ded7dadaec0f83fa75a1ca97a1b.jpg: 640x640 (no detections), 8.0ms
# image 2/513 /content/drive/MyDrive/Real_time_detection_using_yolov/valid/images/00cd18c5aff4548b_jpg.rf.bd1663cdc9106926c3d3507ce963788f.jpg: 640x640 (no detections), 7.4ms
# image 3/513 /content/drive/MyDrive/Real_time_detection_using_yolov/valid/images/037928f436eb68b7_jpg.rf.005d7558814edb8bdf5f858bd336ee4f.jpg: 640x640 1 pen, 7.4ms
# image 4/513 /content/drive/MyDrive/Real_time_detection_using_yolov/valid/images/03dee3ad60e03742_jpg.rf.78a4fd2f41b73241bc0c35949de7866b.jpg: 640x640 3 pens, 8.5ms
# image 5/513 /content/drive/MyDrive/Real_time_detection_using_yolov/valid/images/0491eaba4cf4a9ea_jpg.rf.f09eb035d92b59d7ee29693b1fbb6271.jpg: 640x640 (no detections), 7.4ms
# ...
